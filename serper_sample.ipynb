# %% [markdown]
# ## This is for sample Code to check its working or not

# %%
import os
import requests
from dotenv import load_dotenv
import json 

load_dotenv()

SERPER_API_KEY = os.getenv("SERPER_API_KEY")

# %%
query = "Lithium battery"
url = f"https://serpapi.com/search?engine=google_patents&q={query}&api_key={SERPER_API_KEY}"

response = requests.get(url)
print(response)
if response.status_code == 200:
    data = response.json()
    patents = data.get("organic_results")
    print(patents)
    # if patents:
    #     with open("files/patents.json" , "w") as file:
    #         json.dump(patents , file , indent=4)
# Out:
# <Response [200]>
# [{'position': 1, 'rank': 0, 'patent_id': 'patent/CN119480895B/en', 'patent_link': 'https://patents.google.com/patent/CN119480895B/en', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN119480895B%2Fen', 'title': 'Electrode assemblies, battery cells, batteries, and electrical devices', 'snippet': 'In the present application, the battery cells may include a lithium ion secondary battery cell, a lithium ion primary battery cell, a lithium sulfur battery cell, a sodium lithium ion battery cell, a sodium ion battery cell, or a magnesium ion battery cell, which is not limited in the embodiment of …', 'priority_date': '2021-02-04', 'filing_date': '2021-02-04', 'grant_date': '2025-12-05', 'publication_date': '2025-12-05', 'inventor': '唐彬杰', 'assignee': '宁德时代新能源科技股份有限公司', 'publication_number': 'CN119480895B', 'language': 'en', 'country_status': {'WO': 'NOT_ACTIVE', 'EP': 'ACTIVE', 'US': 'ACTIVE', 'CN': 'ACTIVE', 'HU': 'UNKNOWN'}}, {'position': 2, 'rank': 1, 'patent_id': 'patent/EP4207358A3/en', 'patent_link': 'https://patents.google.com/patent/EP4207358A3/en', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FEP4207358A3%2Fen', 'title': 'Lithium secondary batteries', 'snippet': 'The invention provides a lithium secondary battery including an ionic provider added to the positive electrode. The ionic provider does not involve in the electrochemical reaction of the lithium secondary battery during charging and discharging. The ionic provider can absorb thermal energy caused …', 'priority_date': '2022-01-04', 'filing_date': '2022-12-20', 'publication_date': '2023-07-12', 'inventor': 'Szu-Nan Yang', 'assignee': 'Prologium Technology Co., Ltd.', 'publication_number': 'EP4207358A3', 'language': 'en', 'pdf': 'https://patentimages.storage.googleapis.com/fd/6d/bc/d854352a610c40/EP4207358A3.pdf', 'country_status': {'EP': 'ACTIVE', 'US': 'ACTIVE', 'CN': 'ACTIVE', 'JP': 'ACTIVE', 'KR': 'ACTIVE', 'TW': 'ACTIVE'}}, {'position': 3, 'rank': 2, 'patent_id': 'patent/CN111181207B/en', 'patent_link': 'https://patents.google.com/patent/CN111181207B/en', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN111181207B%2Fen', 'title': 'Distributed lithium battery pack energy storage system', 'snippet': '2. The distributed lithium battery pack energy storage system according to claim 1, wherein the state monitoring data of the battery pack includes the battery pack terminal voltage, the battery pack output current and the battery pack temperature; the microcontroller adopts an equivalent circuit …', 'priority_date': '2020-01-07', 'filing_date': '2020-01-07', 'grant_date': '2021-09-21', 'publication_date': '2021-09-21', 'inventor': '章治国', 'assignee': '重庆理工大学', 'publication_number': 'CN111181207B', 'language': 'en', 'thumbnail': 'https://patentimages.storage.googleapis.com/8a/eb/f6/633ac79bbb5250/HDA0002358241940000011.png', 'pdf': 'https://patentimages.storage.googleapis.com/de/8d/70/732e8d5e735921/CN111181207B.pdf', 'figures': [{'thumbnail': 'https://patentimages.storage.googleapis.com/b5/38/72/9eb118f34ff550/HDA0002358241940000011.png', 'full': 'https://patentimages.storage.googleapis.com/ad/cb/bb/f7c91e380f6880/HDA0002358241940000011.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/e4/7a/74/75fbb51c180292/HDA0002358241940000021.png', 'full': 'https://patentimages.storage.googleapis.com/6b/8f/63/ae2cc229ba4ac2/HDA0002358241940000021.png'}, {'thumbnail': 'https://patentimages.storage.googleapis.com/2d/0b/d9/ed00fe6a539360/HDA0002358241940000022.png', 'full': 'https://patentimages.storage.googleapis.com/58/c3/db/a1a3549b521eb0/HDA0002358241940000022.png'}], 'country_status': {'CN': 'ACTIVE'}}, {'position': 4, 'rank': 3, 'patent_id': 'patent/PL4293783T3/en', 'patent_link': 'https://patents.google.com/patent/PL4293783T3/en', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&pa ...

# %%
def get_data_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise ValueError("Content not found")

# %%
def get_serpapi_url(data , api_key = SERPER_API_KEY):
    """
        Construct the serp api URL from the provided data
        Args:
            data(dict) : The data containing the serpapi url
        Returns:
            Complete serpapi url with the serpapi key as well
    """
    
    # Get the url from the data 
    serpapi_url = data['serpapi_link']

    # Add Api key to URL if its not present
    if "api_key=" not in serpapi_url:
        seperator = "&" if "?" in serpapi_url else "?"
        serpapi_url = f"{serpapi_url}{seperator}api_key={api_key}"

    return serpapi_url

# %%
def main_retrival_function(query : str):
    SERPER_API_KEY = os.getenv("SERPER_API_KEY")
    url = f"https://serpapi.com/search?engine=google_patents&q={query}&api_key={SERPER_API_KEY}"

    # First get the result from the url
    response = requests.get(url)
    if response.status_code == 200:
        try:
            data = response.json()
            patents = data.get("organic_results")
        except Exception as e:
            print("Error in Fetch first :- " , str(e))
    
        # Getting top 3 results
        top_3_main_results = []
        if len(patents) > 3:
            for i in range(3):
                top_3_main_results.append(patents[i])
            print("Got 3 Results and saved in the variable")
        else:
            print("Issue in system for basic fetch")
            raise ValueError("Cant Fetch Properly")
        

        for i in range(3):
            result = top_3_main_results[i]
            if result:
                serper_api_link = get_serpapi_url(result)

# %%
main_retrival_function("Lithium Battery")

# %%
top_3_main_res = []

for i in range(3):
    top_3_main_res.append(patents[i])

# %%
sample_result = top_3_main_res[0]

# %%
sample_first_link = sample_result['serpapi_link']

# %%
sample_serper_api_link_url = sample_first_link + "&api_key=" + SERPER_API_KEY

# %%
sample_serper_api_link_url

# %%
response = requests.get(sample_serper_api_link_url)
if response.status_code == 200:
    data = response.json()

# %%
data['abstract']

# %%
def get_data_from_url(url , api_key):
    generated_url = url + "&api_key=" + SERPER_API_KEY
    response = requests.get(generated_url)
    if response.status_code == 200:
        return response.json()
    else:
        raise ValueError("Content not found")

# %%
aabbcc = get_data_from_url(sample_result['serpapi_link'] , SERPER_API_KEY)

# %%
aabbcc['patent_citations']['original']

# %%
def main_retrival_function(query : str):
    SERPER_API_KEY = os.getenv("SERPER_API_KEY")
    url = f"https://serpapi.com/search?engine=google_patents&q={query}&api_key={SERPER_API_KEY}"

    # First get the result from the url
    response = requests.get(url)
    if response.status_code == 200:
        try:
            data = response.json()
            patents = data.get("organic_results")
        except Exception as e:
            print("Error in Fetch first :- " , str(e))
    
        # Getting top 3 results
        top_3_main_results = []
        if len(patents) > 3:
            for i in range(3):
                top_3_main_results.append(patents[i])
            print("Got 3 Results and saved in the variable")
        else:
            print("Issue in system for basic fetch")
            raise ValueError("Cant Fetch Properly")
        

        for i in range(3):
            result = top_3_main_results[i]
            if result:
                serper_api_link = get_serpapi_url(result)

# %%
def fetch_insider_func(main_data : json):
    top_3_results = []
    patents = main_data.get("organic_results")
    if len(patents) > 3:
        for i in range(3):
            top_3_results.append(patents[i])
        print("Got 3 results and returning to the main")
        print(top_3_results)
        return top_3_results
    else:
        raise ValueError("Cant get organic result from the data")

# %%
load_dotenv()
print(os.getenv("SERPER_API_KEY"))
print(os.getenv(""))

# %%
def get_serpapi_url(data):
    """
        Construct the serp api URL from the provided data
        Args:
            data(dict) : The data containing the serpapi url
        Returns:
            Complete serpapi url with the serpapi key as well
    """
    
    # Get the url from the data 
    serpapi_url = data['serpapi_link']
    api_key = os.getenv("SERPER_API_KEY")

    # Add Api key to URL if its not present
    if "api_key=" not in serpapi_url:
        seperator = "&" if "?" in serpapi_url else "?"
        serpapi_url = f"{serpapi_url}{seperator}api_key={api_key}"
        print(serpapi_url)

    return serpapi_url

# %%
def get_data_and_save_to_file(url : str , count : int , file_abb : str):
    # Fetch data from the url
    try:
        response = requests.get(url)
    except Exception as e:
        raise ValueError("Error in save_data for fetching the data from url" , str(e))
    # Convert data into JSON
    try:
        os.makedirs("results" , exist_ok=True)
    except Exception as e:
        print("Error in Directory making")
    try:
        with open(f"results/{file_abb}_{count}.json" , "w") as f:
            json.dump(response.json() , f , indent=2) 
            count += 1
            print("f{count} file save")
            return count , response.json()
    except Exception as e:
        raise ValueError("Error in file write...." , str(e))

# %%
def get_and_save_data_from_query(query : str):
    count = 1
    SERPER_API_KEY = os.getenv("SERPER_API_KEY")
    url = f"https://serpapi.com/search?engine=google_patents&q={query}&api_key={SERPER_API_KEY}"

    # Getting the response from the main URL
    try:
        main_response = requests.get(url)
    except Exception as e:
        print("Cant get data from the main URL :- " , str(e))
        raise ValueError("Cant Decode the main Response from the url")
    if main_response.status_code == 200:
        try:
            # go inside the data to get detailed data
            main_url_data = main_response.json()
            print(main_url_data)
            top_3_result = fetch_insider_func(main_url_data)
            tp_count = 0
            for tp3 in top_3_result:
                tp_count += 1
                # Main condition to break the loop and exit 
                if count == 11:
                    return

                # Go inside the main result to get the top3
                main_result_serp_url = get_serpapi_url(tp3)
                count , content_data  = get_data_and_save_to_file(main_result_serp_url , count=count , file_abb=f"patent_data__{tp_count}")

                # Go inside each of the patent for citations patent content 
                citation_arr = content_data.get("patent_citations",{}).get("original" , {})
                print(citation_arr)
                if len(citation_arr) >= 1:
                    temp = 0
                    for cit in citation_arr:
                        if count < 11:
                            if temp < 3:
                                citation_serp_url = get_serpapi_url(cit)
                                count , _ = get_data_and_save_to_file(citation_serp_url , count , f"citaion_data__{tp_count}")
                                temp += 1
                            else:
                                break
                        else:
                            return
                print("Total File Added :- " , count)
        except Exception as e:
            print("Error in converting data to JSON from main url : " , str(e))
            return 
    else:
        raise ValueError("Response Status code is not 200!!")

# %%
arr_sample = get_and_save_data_from_query("EV Cars")

# %%
ipynb is running good but issue is in python file 

Complete embeddings 
CrewAgent
